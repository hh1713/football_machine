# %%
import pandas

# %%
pandas.read_csv('belgium.csv')
# Out:
#      Unnamed: 0                 Date     HomeTeam     AwayTeam  FTHG  FTAG  \
# 0             0             19/08/16    La Coruna        Eibar   2.0   1.0
# 1             1             19/08/16       Malaga      Osasuna   1.0   1.0
# 2             2             20/08/16    Barcelona        Betis   6.0   2.0
# 3             3             20/08/16      Granada   Villarreal   1.0   1.0
# 4             4             20/08/16      Sevilla      Espanol   6.0   4.0
# 5             5             21/08/16   Ath Madrid       Alaves   1.0   1.0
# 6             6             21/08/16     Sociedad  Real Madrid   0.0   3.0
# 7             7             21/08/16     Sp Gijon   Ath Bilbao   2.0   1.0
# 8             8             22/08/16        Celta      Leganes   0.0   1.0
# 9             9             22/08/16     Valencia   Las Palmas   2.0   4.0
# 10           10             26/08/16        Betis    La Coruna   0.0   0.0
# ...

# %%
a =  pandas.read_csv('.csv').iloc[-1]

# %%
a
# Out:
# Unnamed: 0                             348
# Date                   2017-01-05 00:00:00
# HomeTeam                            Malaga
# AwayTeam                           Sevilla
# FTHG                                     0
# FTAG                                     0
# FTR                                      D
# season                           2016/2017
# H_ROUND                                 35
# H_TP3                                    6
# H_TP5                                   12
# H_GS_H                                  25
# H_GS_A                                  15
# H_GR_H                                  21
# H_GR_A                                  28
# H_TGS                                   40
# H_TGR                                   49
# H_AvGS_H                            1.5625
# H_AvGS_A                          0.833333
# H_AvGR_H                            1.3125
# H_AvGR_A                           1.55556
# H_Av_TGS                           1.17647
# ...

# %%
for i in [91,92,94,95,103]:
    a[91]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-e7a80f0bfb1e> in <module>()
#       1 for i in [91,92,94,95,103]:
# ----> 2     a[91]
#
# /Users/nicolamacchitella/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     601         key = com._apply_if_callable(key, self)
#     602         try:
# --> 603             result = self.index.get_value(self, key)
#     604
#     605             if not is_scalar(result):
#
# /Users/nicolamacchitella/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_value(self, series, key)
#    2173
#    2174             try:
# -> 2175                 return tslib.get_value_box(s, key)
#    2176             except IndexError:
#    2177                 raise
#
# pandas/tslib.pyx in pandas.tslib.get_value_box (pandas/tslib.c:19053)()
#
# ...
