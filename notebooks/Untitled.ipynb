# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/EPL_1617.csv")

# %%
season = df.iloc[:,1:11]

# %%
columns = ['Date', 'HomeTeam', 'AwayTeam', 
           'FullTimeHomeGoals', 'FullTimeAwayGoals', 'FullTimeResults', 
           'HalfTimeHomeGoals', 'HalfTimeAwayGoals', 'HalfTimeResults', 'Referee']

# %%
#season.columns = columns

# %%
season.HomeTeam.unique()
# Out:
# array(['Burnley', 'Crystal Palace', 'Everton', 'Hull', 'Man City',
#        'Middlesbrough', 'Southampton', 'Arsenal', 'Bournemouth', 'Chelsea',
#        'Man United', 'Leicester', 'Stoke', 'Swansea', 'Tottenham',
#        'Watford', 'West Brom', 'Sunderland', 'West Ham', 'Liverpool'], dtype=object)

# %%
for i in season.HomeTeam.unique():
    df_%s %i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-2834f9591819> in <module>()
#       1 for i in season.HomeTeam.unique():
# ----> 2     df_%s %i
#       3
#
# NameError: name 'df_' is not defined

# %%
arsenal_1617 = season[(season["HomeTeam"] == 'Arsenal') | (season['AwayTeam'] == 'Arsenal')]

# %%
arsenal_1617
# Out:
#          Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 7    14/08/16      Arsenal       Liverpool     3     4   A     1     1   D
# 12   20/08/16    Leicester         Arsenal     0     0   D     0     0   D
# 27   27/08/16      Watford         Arsenal     1     3   A     0     3   A
# 30   10/09/16      Arsenal     Southampton     2     1   H     1     1   D
# 42   17/09/16         Hull         Arsenal     1     4   A     0     1   A
# 50   24/09/16      Arsenal         Chelsea     3     0   H     3     0   H
# 66   02/10/16      Burnley         Arsenal     0     1   A     0     0   D
# 70   15/10/16      Arsenal         Swansea     3     2   H     2     1   H
# 80   22/10/16      Arsenal   Middlesbrough     0     0   D     0     0   D
# 93   29/10/16   Sunderland         Arsenal     1     4   A     0     1   A
# 105  06/11/16      Arsenal       Tottenham     1     1   D     1     0   H
# ...

# %%
def calc_points_and_goals(df):
    for row in df:
        print row

# %%
calc_points_and_goals(arsenal_1617)
# Out:
# Date
# HomeTeam
# AwayTeam
# FTHG
# FTAG
# FTR
# HTHG
# HTAG
# HTR
# Referee

# %%
for i in
